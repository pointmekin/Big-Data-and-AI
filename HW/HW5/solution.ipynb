# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import impute
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from statsmodels.stats.outliers_influence import variance_inflation_factor
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Load Data

# %%
df = pd.read_csv("./movie_metadata.csv")

# %%
df.head()
# Out:
#        director_name  num_critic_for_reviews  duration  \
# 0      James Cameron                   723.0     178.0
# 1     Gore Verbinski                   302.0     169.0
# 2         Sam Mendes                   602.0     148.0
# 3  Christopher Nolan                   813.0     164.0
# 4        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0          NaN                      Documentary
#
#       actor_1_name  ... num_user_for_reviews  language  country  \
# 0      CCH Pounder  ...               3054.0   English      USA
# 1      Johnny Depp  ...               1238.0   English      USA
# 2  Christoph Waltz  ...                994.0   English       UK
# 3        Tom Hardy  ...               2701.0   English      USA
# 4      Doug Walker  ...                  NaN       NaN      NaN
#
#   content_rating       budget title_year actor_2_facebook_likes  imdb_score  \
# 0          PG-13  237000000.0     2009.0                  936.0         7.9
# 1          PG-13  300000000.0     2007.0                 5000.0         7.1
# 2          PG-13  245000000.0     2015.0                  393.0         6.8
# 3          PG-13  250000000.0     2012.0                23000.0         8.5
# 4            NaN          NaN        NaN                   12.0         7.1
#
#   aspect_ratio movie_facebook_likes
# 0         1.78                33000
# 1         2.35                    0
# 2         2.35                85000
# 3         2.35               164000
# 4          NaN                    0
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Explore Data

# %%
df.shape
# Out:
# (5043, 27)

# %%
df.describe().T.round(1)
# Out:
#                             count        mean          std     min        25%  \
# num_critic_for_reviews     4993.0       140.2        121.6     1.0       50.0
# duration                   5028.0       107.2         25.2     7.0       93.0
# director_facebook_likes    4939.0       686.5       2813.3     0.0        7.0
# actor_3_facebook_likes     5020.0       645.0       1665.0     0.0      133.0
# actor_1_facebook_likes     5036.0      6560.0      15020.8     0.0      614.0
# gross                      4159.0  48468407.5   68452990.4   162.0  5340987.5
# num_voted_users            5043.0     83668.2     138485.3     5.0     8593.5
# cast_total_facebook_likes  5043.0      9699.1      18163.8     0.0     1411.0
# facenumber_in_poster       5030.0         1.4          2.0     0.0        0.0
# num_user_for_reviews       5022.0       272.8        378.0     1.0       65.0
# budget                     4551.0  39752620.4  206114898.4   218.0  6000000.0
# title_year                 4935.0      2002.5         12.5  1916.0     1999.0
# actor_2_facebook_likes     5030.0      1651.8       4042.4     0.0      281.0
# imdb_score                 5043.0         6.4          1.1     1.6        5.8
# aspect_ratio               4714.0         2.2          1.4     1.2        1.8
# movie_facebook_likes       5043.0      7526.0      19320.4     0.0        0.0
#
#                                   50%         75%           max
# num_critic_for_reviews          110.0       195.0  8.130000e+02
# duration                        103.0       118.0  5.110000e+02
# director_facebook_likes          49.0       194.5  2.300000e+04
# actor_3_facebook_likes          371.5       636.0  2.300000e+04
# actor_1_facebook_likes          988.0     11000.0  6.400000e+05
# gross                      25517500.0  62309437.5  7.605058e+08
# num_voted_users               34359.0     96309.0  1.689764e+06
# cast_total_facebook_likes      3090.0     13756.5  6.567300e+05
# facenumber_in_poster              1.0         2.0  4.300000e+01
# num_user_for_reviews            156.0       326.0  5.060000e+03
# budget                     20000000.0  45000000.0  1.221550e+10
# title_year                     2005.0      2011.0  2.016000e+03
# actor_2_facebook_likes          595.0       918.0  1.370000e+05
# imdb_score                        6.6         7.2  9.500000e+00
# aspect_ratio                      2.4         2.4  1.600000e+01
# movie_facebook_likes            166.0      3000.0  3.490000e+05

# %%
numerical_cols = df._get_numeric_data().columns.tolist()

# %%
numerical_cols
# Out:
# ['num_critic_for_reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_1_facebook_likes',
#  'gross',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'facenumber_in_poster',
#  'num_user_for_reviews',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes']

# %%
numerical_features=list(set(numerical_cols)-set(['imdb_score']))
numerical_features
# Out:
# ['num_user_for_reviews',
#  'facenumber_in_poster',
#  'aspect_ratio',
#  'actor_2_facebook_likes',
#  'movie_facebook_likes',
#  'actor_1_facebook_likes',
#  'duration',
#  'actor_3_facebook_likes',
#  'num_critic_for_reviews',
#  'cast_total_facebook_likes',
#  'budget',
#  'gross',
#  'director_facebook_likes',
#  'title_year',
#  'num_voted_users']

# %%
numerical_cols=numerical_features.copy()
numerical_cols.append('imdb_score')

# %%
numerical_cols
# Out:
# ['num_user_for_reviews',
#  'facenumber_in_poster',
#  'aspect_ratio',
#  'actor_2_facebook_likes',
#  'movie_facebook_likes',
#  'actor_1_facebook_likes',
#  'duration',
#  'actor_3_facebook_likes',
#  'num_critic_for_reviews',
#  'cast_total_facebook_likes',
#  'budget',
#  'gross',
#  'director_facebook_likes',
#  'title_year',
#  'num_voted_users',
#  'imdb_score']

# %%
categorical_features=list(set(df.columns.tolist())-set(numerical_cols))
categorical_features
# Out:
# ['actor_2_name',
#  'director_name',
#  'actor_3_name',
#  'movie_imdb_link',
#  'language',
#  'content_rating',
#  'movie_title',
#  'plot_keywords',
#  'country',
#  'genres',
#  'actor_1_name']

# %%
df['country'].value_counts()
# Out:
# USA              3807
# UK                448
# France            154
# Canada            126
# Germany            97
#                  ...
# Slovakia            1
# Chile               1
# Cambodia            1
# Official site       1
# Philippines         1
# Name: country, Length: 65, dtype: int64

# %%
df.describe(exclude=np.number).T
# Out:
#                 count unique  \
# director_name    4939   2398
# actor_2_name     5030   3032
# genres           5043    914
# actor_1_name     5036   2097
# movie_title      5043   4917
# actor_3_name     5020   3521
# plot_keywords    4890   4760
# movie_imdb_link  5043   4919
# language         5031     47
# country          5038     65
# content_rating   4740     18
#
#                                                                top  freq
# director_name                                     Steven Spielberg    26
# actor_2_name                                        Morgan Freeman    20
# genres                                                       Drama   236
# actor_1_name                                        Robert De Niro    49
# movie_title                                               Ben-Hur      3
# actor_3_name                                            John Heard     8
# plot_keywords                                       based on novel     4
# movie_imdb_link  http://www.imdb.com/title/tt0232500/?ref_=fn_t...     3
# language                                                   English  4704
# country                                                        USA  3807
# content_rating                                                   R  2118

# %%
df_nums = df[numerical_cols]

# %%
df_nums.head()
# Out:
#    num_user_for_reviews  facenumber_in_poster  aspect_ratio  \
# 0                3054.0                   0.0          1.78
# 1                1238.0                   0.0          2.35
# 2                 994.0                   1.0          2.35
# 3                2701.0                   0.0          2.35
# 4                   NaN                   0.0           NaN
#
#    actor_2_facebook_likes  movie_facebook_likes  actor_1_facebook_likes  \
# 0                   936.0                 33000                  1000.0
# 1                  5000.0                     0                 40000.0
# 2                   393.0                 85000                 11000.0
# 3                 23000.0                164000                 27000.0
# 4                    12.0                     0                   131.0
#
#    duration  actor_3_facebook_likes  num_critic_for_reviews  \
# 0     178.0                   855.0                   723.0
# 1     169.0                  1000.0                   302.0
# 2     148.0                   161.0                   602.0
# 3     164.0                 23000.0                   813.0
# 4       NaN                     NaN                     NaN
#
#    cast_total_facebook_likes       budget        gross  \
# 0                       4834  237000000.0  760505847.0
# 1                      48350  300000000.0  309404152.0
# 2                      11700  245000000.0  200074175.0
# 3                     106759  250000000.0  448130642.0
# 4                        143          NaN          NaN
#
#    director_facebook_likes  title_year  num_voted_users  imdb_score
# 0                      0.0      2009.0           886204         7.9
# 1                    563.0      2007.0           471220         7.1
# 2                      0.0      2015.0           275868         6.8
# 3                  22000.0      2012.0          1144337         8.5
# 4                    131.0         NaN                8         7.1

# %%
df_nums.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   num_user_for_reviews       5022 non-null   float64
#  1   facenumber_in_poster       5030 non-null   float64
#  2   aspect_ratio               4714 non-null   float64
#  3   actor_2_facebook_likes     5030 non-null   float64
#  4   movie_facebook_likes       5043 non-null   int64
#  5   actor_1_facebook_likes     5036 non-null   float64
#  6   duration                   5028 non-null   float64
#  7   actor_3_facebook_likes     5020 non-null   float64
#  8   num_critic_for_reviews     4993 non-null   float64
#  9   cast_total_facebook_likes  5043 non-null   int64
#  10  budget                     4551 non-null   float64
#  11  gross                      4159 non-null   float64
#  12  director_facebook_likes    4939 non-null   float64
#  13  title_year                 4935 non-null   float64
#  14  num_voted_users            5043 non-null   int64
#  15  imdb_score                 5043 non-null   float64
# dtypes: float64(13), int64(3)
# memory usage: 630.5 KB

# %%
#Check missing values
(df_nums.isnull().sum()*100/len(df_nums)).sort_values(ascending=False)
# Out:
# gross                        17.529248
# budget                        9.756098
# aspect_ratio                  6.523895
# title_year                    2.141582
# director_facebook_likes       2.062265
# num_critic_for_reviews        0.991473
# actor_3_facebook_likes        0.456078
# num_user_for_reviews          0.416419
# duration                      0.297442
# facenumber_in_poster          0.257783
# actor_2_facebook_likes        0.257783
# actor_1_facebook_likes        0.138806
# movie_facebook_likes          0.000000
# cast_total_facebook_likes     0.000000
# num_voted_users               0.000000
# imdb_score                    0.000000
# dtype: float64

# %%
df_nums.describe().round(2).T
# Out:
#                             count         mean           std      min  \
# num_user_for_reviews       5022.0       272.77  3.779800e+02     1.00
# facenumber_in_poster       5030.0         1.37  2.010000e+00     0.00
# aspect_ratio               4714.0         2.22  1.390000e+00     1.18
# actor_2_facebook_likes     5030.0      1651.75  4.042440e+03     0.00
# movie_facebook_likes       5043.0      7525.96  1.932045e+04     0.00
# actor_1_facebook_likes     5036.0      6560.05  1.502076e+04     0.00
# duration                   5028.0       107.20  2.520000e+01     7.00
# actor_3_facebook_likes     5020.0       645.01  1.665040e+03     0.00
# num_critic_for_reviews     4993.0       140.19  1.216000e+02     1.00
# cast_total_facebook_likes  5043.0      9699.06  1.816380e+04     0.00
# budget                     4551.0  39752620.44  2.061149e+08   218.00
# gross                      4159.0  48468407.53  6.845299e+07   162.00
# director_facebook_likes    4939.0       686.51  2.813330e+03     0.00
# title_year                 4935.0      2002.47  1.247000e+01  1916.00
# num_voted_users            5043.0     83668.16  1.384853e+05     5.00
# imdb_score                 5043.0         6.44  1.130000e+00     1.60
#
#                                   25%          50%          75%           max
# num_user_for_reviews            65.00       156.00       326.00  5.060000e+03
# facenumber_in_poster             0.00         1.00         2.00  4.300000e+01
# aspect_ratio                     1.85         2.35         2.35  1.600000e+01
# actor_2_facebook_likes         281.00       595.00       918.00  1.370000e+05
# movie_facebook_likes             0.00       166.00      3000.00  3.490000e+05
# actor_1_facebook_likes         614.00       988.00     11000.00  6.400000e+05
# duration                        93.00       103.00       118.00  5.110000e+02
# actor_3_facebook_likes         133.00       371.50       636.00  2.300000e+04
# num_critic_for_reviews          50.00       110.00       195.00  8.130000e+02
# cast_total_facebook_likes     1411.00      3090.00     13756.50  6.567300e+05
# budget                     6000000.00  20000000.00  45000000.00  1.221550e+10
# gross                      5340987.50  25517500.00  62309437.50  7.605058e+08
# director_facebook_likes          7.00        49.00       194.50  2.300000e+04
# title_year                    1999.00      2005.00      2011.00  2.016000e+03
# num_voted_users               8593.50     34359.00     96309.00  1.689764e+06
# imdb_score                       5.80         6.60         7.20  9.500000e+00

# %%
df_nums.hist(bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'num_user_for_reviews'}>,
#         <AxesSubplot:title={'center':'facenumber_in_poster'}>,
#         <AxesSubplot:title={'center':'aspect_ratio'}>,
#         <AxesSubplot:title={'center':'actor_2_facebook_likes'}>],
#        [<AxesSubplot:title={'center':'movie_facebook_likes'}>,
#         <AxesSubplot:title={'center':'actor_1_facebook_likes'}>,
#         <AxesSubplot:title={'center':'duration'}>,
#         <AxesSubplot:title={'center':'actor_3_facebook_likes'}>],
#        [<AxesSubplot:title={'center':'num_critic_for_reviews'}>,
#         <AxesSubplot:title={'center':'cast_total_facebook_likes'}>,
#         <AxesSubplot:title={'center':'budget'}>,
#         <AxesSubplot:title={'center':'gross'}>],
#        [<AxesSubplot:title={'center':'director_facebook_likes'}>,
#         <AxesSubplot:title={'center':'title_year'}>,
#         <AxesSubplot:title={'center':'num_voted_users'}>,
#         <AxesSubplot:title={'center':'imdb_score'}>]], dtype=object)

# %%
#The variables with skewness > 1 such as wheelbase, compressionratio, horsepower, price are highly positively skewed.
#The variables with skewness < -1 are highly negatively skewed.
#The variables with 0.5 < skewness < 1 such as carwidth, curbweight, citympg are moderately positively skewed.
# The variables with -0.5 < skewness < -1 such as stroke are moderately negatively skewed.
# And, the variables with -0.5 < skewness < 0.5 are symmetric i.e normally distributed such as symboling, carheight, boreration, peakrpm, highwaympg.
df_nums.skew().sort_values()
# Out:
# title_year                   -2.292273
# imdb_score                   -0.741471
# num_critic_for_reviews        1.516533
# duration                      2.339134
# gross                         3.127204
# num_voted_users               4.029871
# num_user_for_reviews          4.121475
# facenumber_in_poster          4.384766
# movie_facebook_likes          5.058927
# director_facebook_likes       5.229701
# actor_3_facebook_likes        7.279021
# aspect_ratio                  9.390056
# actor_2_facebook_likes        9.884733
# cast_total_facebook_likes    12.831928
# actor_1_facebook_likes       19.121776
# budget                       48.157435
# dtype: float64

# %% [markdown]
# #### Preprocess Data

# %%
df_nums.isna().sum()
# Out:
# num_user_for_reviews          21
# facenumber_in_poster          13
# aspect_ratio                 329
# actor_2_facebook_likes        13
# movie_facebook_likes           0
# actor_1_facebook_likes         7
# duration                      15
# actor_3_facebook_likes        23
# num_critic_for_reviews        50
# cast_total_facebook_likes      0
# budget                       492
# gross                        884
# director_facebook_likes      104
# title_year                   108
# num_voted_users                0
# imdb_score                     0
# dtype: int64

# %%
df_nums.shape
# Out:
# (5043, 16)

# %%
df_nums['imdb_score'].quantile(q=[0.4,0.5,0.6])
# Out:
# 0.4    6.3
# 0.5    6.6
# 0.6    6.8
# Name: imdb_score, dtype: float64

# %%
df_nums['imdb_cut']=df_nums['imdb_score'].apply(lambda x:0 if x<=6.3 else(1 if x>=6.8 else 'middle'))

# %%
df_nums['imdb_cut'].value_counts()
# Out:
# 1         2133
# 0         2115
# middle     795
# Name: imdb_cut, dtype: int64

# %%
795/len(df)
# Out:
# 0.15764425936942297

# %%
df_nums_1=df_nums.drop(df_nums[df_nums['imdb_cut']=='middle'].index)
df_nums_1['imdb_cut'].value_counts()
# Out:
# 1    2133
# 0    2115
# Name: imdb_cut, dtype: int64

# %%
df_nums_1.head()
# Out:
#    num_user_for_reviews  facenumber_in_poster  aspect_ratio  \
# 0                3054.0                   0.0          1.78
# 1                1238.0                   0.0          2.35
# 2                 994.0                   1.0          2.35
# 3                2701.0                   0.0          2.35
# 4                   NaN                   0.0           NaN
#
#    actor_2_facebook_likes  movie_facebook_likes  actor_1_facebook_likes  \
# 0                   936.0                 33000                  1000.0
# 1                  5000.0                     0                 40000.0
# 2                   393.0                 85000                 11000.0
# 3                 23000.0                164000                 27000.0
# 4                    12.0                     0                   131.0
#
#    duration  actor_3_facebook_likes  num_critic_for_reviews  \
# 0     178.0                   855.0                   723.0
# 1     169.0                  1000.0                   302.0
# 2     148.0                   161.0                   602.0
# 3     164.0                 23000.0                   813.0
# 4       NaN                     NaN                     NaN
#
#    cast_total_facebook_likes       budget        gross  \
# 0                       4834  237000000.0  760505847.0
# 1                      48350  300000000.0  309404152.0
# 2                      11700  245000000.0  200074175.0
# 3                     106759  250000000.0  448130642.0
# 4                        143          NaN          NaN
#
#    director_facebook_likes  title_year  num_voted_users  imdb_score imdb_cut
# 0                      0.0      2009.0           886204         7.9        1
# 1                    563.0      2007.0           471220         7.1        1
# 2                      0.0      2015.0           275868         6.8        1
# 3                  22000.0      2012.0          1144337         8.5        1
# 4                    131.0         NaN                8         7.1        1

# %%
df_nums_1.columns
# Out:
# Index(['num_user_for_reviews', 'facenumber_in_poster', 'aspect_ratio',
#        'actor_2_facebook_likes', 'movie_facebook_likes',
#        'actor_1_facebook_likes', 'duration', 'actor_3_facebook_likes',
#        'num_critic_for_reviews', 'cast_total_facebook_likes', 'budget',
#        'gross', 'director_facebook_likes', 'title_year', 'num_voted_users',
#        'imdb_score', 'imdb_cut'],
#       dtype='object')

# %%
#1d array (m,1).ravel() or (m,)
#pd.Series index
#pd.DataFrame with single column index and column label
x=df_nums_1.drop(['imdb_score','imdb_cut'],axis=1)
y=df_nums_1['imdb_cut'].to_numpy()

# %%
df_nums_1['imdb_cut'].to_numpy().shape
# Out:
# (4248,)

# %%
y.shape
# Out:
# (4248,)

# %%
y_labels=['imdb_low','imdb_high']

# %%
df_nums_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4248 entries, 0 to 5041
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   num_user_for_reviews       4228 non-null   float64
#  1   facenumber_in_poster       4235 non-null   float64
#  2   aspect_ratio               3960 non-null   float64
#  3   actor_2_facebook_likes     4236 non-null   float64
#  4   movie_facebook_likes       4248 non-null   int64
#  5   actor_1_facebook_likes     4242 non-null   float64
#  6   duration                   4235 non-null   float64
#  7   actor_3_facebook_likes     4228 non-null   float64
#  8   num_critic_for_reviews     4200 non-null   float64
#  9   cast_total_facebook_likes  4248 non-null   int64
#  10  budget                     3817 non-null   float64
#  11  gross                      3454 non-null   float64
#  12  director_facebook_likes    4152 non-null   float64
#  13  title_year                 4148 non-null   float64
#  14  num_voted_users            4248 non-null   int64
#  15  imdb_score                 4248 non-null   float64
#  16  imdb_cut                   4248 non-null   object
# dtypes: float64(13), int64(3), object(1)
# memory usage: 597.4+ KB

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,shuffle=True,stratify=y,random_state=100)
y_train=y_train.astype(int)
y_test=y_test.astype(int)

# %%
x_train.sort_index().head()
# Out:
#    num_user_for_reviews  facenumber_in_poster  aspect_ratio  \
# 0                3054.0                   0.0          1.78
# 2                 994.0                   1.0          2.35
# 3                2701.0                   0.0          2.35
# 4                   NaN                   0.0           NaN
# 7                 387.0                   1.0          1.85
#
#    actor_2_facebook_likes  movie_facebook_likes  actor_1_facebook_likes  \
# 0                   936.0                 33000                  1000.0
# 2                   393.0                 85000                 11000.0
# 3                 23000.0                164000                 27000.0
# 4                    12.0                     0                   131.0
# 7                   553.0                 29000                   799.0
#
#    duration  actor_3_facebook_likes  num_critic_for_reviews  \
# 0     178.0                   855.0                   723.0
# 2     148.0                   161.0                   602.0
# 3     164.0                 23000.0                   813.0
# 4       NaN                     NaN                     NaN
# 7     100.0                   284.0                   324.0
#
#    cast_total_facebook_likes       budget        gross  \
# 0                       4834  237000000.0  760505847.0
# 2                      11700  245000000.0  200074175.0
# 3                     106759  250000000.0  448130642.0
# 4                        143          NaN          NaN
# 7                       2036  260000000.0  200807262.0
#
#    director_facebook_likes  title_year  num_voted_users
# 0                      0.0      2009.0           886204
# 2                      0.0      2015.0           275868
# 3                  22000.0      2012.0          1144337
# 4                    131.0         NaN                8
# 7                     15.0      2010.0           294810

# %%
x_train.shape
# Out:
# (2973, 15)

# %%
x_train.describe()
# Out:
#        num_user_for_reviews  facenumber_in_poster  aspect_ratio  \
# count           2959.000000           2963.000000   2762.000000
# mean             278.655965              1.331421      2.226738
# std              392.936679              1.966854      1.425877
# min                1.000000              0.000000      1.200000
# 25%               64.000000              0.000000      1.850000
# 50%              159.000000              1.000000      2.350000
# 75%              329.000000              2.000000      2.350000
# max             5060.000000             31.000000     16.000000
#
#        actor_2_facebook_likes  movie_facebook_likes  actor_1_facebook_likes  \
# count             2965.000000           2973.000000             2969.000000
# mean              1603.025632           7446.565758             6494.261704
# std               4245.150715          20061.581475            17487.530710
# min                  0.000000              0.000000                0.000000
# 25%                282.000000              0.000000              606.000000
# 50%                592.000000            158.000000              975.000000
# 75%                898.000000           2000.000000            11000.000000
# max             137000.000000         349000.000000           640000.000000
#
#           duration  actor_3_facebook_likes  num_critic_for_reviews  \
# count  2964.000000             2959.000000             2940.000000
# mean    106.969973              650.682663              139.463605
# std      26.048323             1750.564118              123.376048
# min       7.000000                0.000000                1.000000
# 25%      93.000000              132.000000               49.000000
# 50%     103.000000              368.000000              108.000000
# 75%     117.000000              627.500000              192.000000
# max     511.000000            23000.000000              813.000000
#
#        cast_total_facebook_likes        budget         gross  \
# count                2973.000000  2.653000e+03  2.423000e+03
# mean                 9596.612176  4.090344e+07  4.814273e+07
# std                 20525.599505  2.543049e+08  7.048790e+07
# min                     0.000000  2.180000e+02  1.620000e+02
# 25%                  1379.000000  5.500000e+06  5.705630e+06
# 50%                  3016.000000  1.800000e+07  2.439747e+07
# 75%                 13071.000000  4.000000e+07  5.971586e+07
# max                656730.000000  1.221550e+10  7.605058e+08
#
#        director_facebook_likes   title_year  num_voted_users
# count              2907.000000  2903.000000     2.973000e+03
# mean                680.023048  2002.216672     8.544587e+04
# std                2804.035254    12.722760     1.474329e+05
# min                   0.000000  1916.000000     5.000000e+00
# 25%                   6.000000  1999.000000     8.217000e+03
# 50%                  44.000000  2005.000000     3.239900e+04
# 75%                 192.000000  2011.000000     9.246100e+04
# max               22000.000000  2016.000000     1.689764e+06

# %% [markdown]
# ##### Change distribution to be normalized

# %%
powertran=preprocessing.PowerTransformer()
powertran=powertran.fit(x_train)
x_train=pd.DataFrame(powertran.transform(x_train),columns=x_train.columns)
x_train.head()
# Out:
#    num_user_for_reviews  facenumber_in_poster  aspect_ratio  \
# 0             -0.993857             -1.048678     -0.639743
# 1             -0.404985              0.899262     -0.896681
# 2              1.210289             -1.048678     -0.639743
# 3              0.474722             -1.048678     -0.639743
# 4              0.004082              1.434581     -0.639743
#
#    actor_2_facebook_likes  movie_facebook_likes  actor_1_facebook_likes  \
# 0               -0.306605              0.607972               -0.481017
# 1                0.288557              1.183027               -0.290918
# 2                0.367064              1.256336               -0.296795
# 3                0.154100              1.370346                1.325590
# 4                0.281349              1.215854               -0.307640
#
#    duration  actor_3_facebook_likes  num_critic_for_reviews  \
# 0  0.373111                0.076214               -0.548083
# 1 -0.731938                0.743956                0.121030
# 2 -0.688175                0.730093                0.344038
# 3  0.020964               -0.039819                1.859988
# 4  0.257330               -0.263727                0.215766
#
#    cast_total_facebook_likes    budget     gross  director_facebook_likes  \
# 0                  -0.327672 -0.064374 -1.671120                 0.645701
# 1                   0.126709 -1.475926 -1.775062                -0.184101
# 2                  -0.068187 -0.316328 -0.357613                 0.991276
# 3                   1.088979  0.405867  0.250806                -1.520837
# 4                  -0.295339  0.517688  0.375621                 0.093067
#
#    title_year  num_voted_users
# 0    0.453136        -0.509705
# 1    0.234625         0.221228
# 2   -0.456064         1.197378
# 3    1.045084         0.979463
# 4    0.800181         0.245750

# %%
powertran.lambdas_
# Out:
# array([ 1.49480248e-01, -6.33919025e-01, -2.14586317e+00,  8.59455455e-02,
#        -4.20929269e-02,  4.91365438e-02,  4.89664131e-01,  1.55867455e-01,
#         3.06795168e-01,  1.35500025e-01,  1.59219753e-01,  2.26026592e-01,
#        -2.36082527e-02,  4.68507943e+01,  1.54335941e-01])

# %%
x_train.hist()
# Out:
# array([[<AxesSubplot:title={'center':'num_user_for_reviews'}>,
#         <AxesSubplot:title={'center':'facenumber_in_poster'}>,
#         <AxesSubplot:title={'center':'aspect_ratio'}>,
#         <AxesSubplot:title={'center':'actor_2_facebook_likes'}>],
#        [<AxesSubplot:title={'center':'movie_facebook_likes'}>,
#         <AxesSubplot:title={'center':'actor_1_facebook_likes'}>,
#         <AxesSubplot:title={'center':'duration'}>,
#         <AxesSubplot:title={'center':'actor_3_facebook_likes'}>],
#        [<AxesSubplot:title={'center':'num_critic_for_reviews'}>,
#         <AxesSubplot:title={'center':'cast_total_facebook_likes'}>,
#         <AxesSubplot:title={'center':'budget'}>,
#         <AxesSubplot:title={'center':'gross'}>],
#        [<AxesSubplot:title={'center':'director_facebook_likes'}>,
#         <AxesSubplot:title={'center':'title_year'}>,
#         <AxesSubplot:title={'center':'num_voted_users'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
x_test=pd.DataFrame(powertran.transform(x_test),columns=x_test.columns)

# %% [markdown]
# ##### fill missing values

# %%
imputer=impute.SimpleImputer(missing_values=np.nan,strategy='median')
imputer.fit(x_train)
x_train=pd.DataFrame(imputer.transform(x_train),columns=x_train.columns)
x_test=pd.DataFrame(imputer.transform(x_test),columns=x_train.columns)

# %% [markdown]
# ##### scale features: not necessary as you did powertransformer already

# %%
scaler=preprocessing.StandardScaler()
scaler.fit(x_train)
x_train=pd.DataFrame(scaler.transform(x_train),columns=x_train.columns)
x_test=pd.DataFrame(scaler.transform(x_test),columns=x_train.columns)

# %% [markdown]
# ##### select feature

# %%
n=len(x_train.columns)
n
# Out:
# 15

# %%
fig,ax=plt.subplots(3,5,figsize=(15,5),sharey=True)
for i in np.arange(0,n):
    col=x_train.columns[i]
    ax[divmod(i,5)[0],divmod(i,5)[1]].scatter(x_train[col],y_train)
    ax[divmod(i,5)[0],divmod(i,5)[1]].set_title(col)
plt.show()

# %%
x_train.corr().mask(x_train.corr().abs()<0.8,'')
# Out:
#                           num_user_for_reviews facenumber_in_poster  \
# num_user_for_reviews                       1.0
# facenumber_in_poster                                            1.0
# aspect_ratio
# actor_2_facebook_likes
# movie_facebook_likes
# actor_1_facebook_likes
# duration
# actor_3_facebook_likes
# num_critic_for_reviews
# cast_total_facebook_likes
# budget
# gross
# director_facebook_likes
# title_year
# num_voted_users                       0.896937
#
#                           aspect_ratio actor_2_facebook_likes  \
# num_user_for_reviews
# facenumber_in_poster
# aspect_ratio                       1.0
# actor_2_facebook_likes                                    1.0
# movie_facebook_likes
# actor_1_facebook_likes
# duration
# actor_3_facebook_likes                               0.830951
# num_critic_for_reviews
# cast_total_facebook_likes                            0.832134
# budget
# gross
# director_facebook_likes
# title_year
# num_voted_users
#
#                           movie_facebook_likes actor_1_facebook_likes  \
# num_user_for_reviews
# facenumber_in_poster
# aspect_ratio
# actor_2_facebook_likes
# movie_facebook_likes                       1.0
# actor_1_facebook_likes                                            1.0
# duration
# actor_3_facebook_likes
# num_critic_for_reviews
# cast_total_facebook_likes                                     0.96761
# budget
# gross
# director_facebook_likes
# title_year
# num_voted_users
#
#                           duration actor_3_facebook_likes  \
# num_user_for_reviews
# facenumber_in_poster
# aspect_ratio
# actor_2_facebook_likes                           0.830951
# movie_facebook_likes
# actor_1_facebook_likes
# duration                       1.0
# actor_3_facebook_likes                                1.0
# num_critic_for_reviews
# cast_total_facebook_likes
# budget
# gross
# director_facebook_likes
# title_year
# num_voted_users
#
#                           num_critic_for_reviews cast_total_facebook_likes  \
# num_user_for_reviews
# facenumber_in_poster
# aspect_ratio
# actor_2_facebook_likes                                            0.832134
# movie_facebook_likes
# actor_1_facebook_likes                                             0.96761
# duration
# actor_3_facebook_likes
# num_critic_for_reviews                       1.0
# cast_total_facebook_likes                                              1.0
# budget
# gross
# director_facebook_likes
# title_year
# num_voted_users                         0.800632
#
#                           budget gross director_facebook_likes title_year  \
# num_user_for_reviews
# facenumber_in_poster
# aspect_ratio
# actor_2_facebook_likes
# movie_facebook_likes
# actor_1_facebook_likes
# duration
# actor_3_facebook_likes
# num_critic_for_reviews
# cast_total_facebook_likes
# budget                       1.0
# gross                              1.0
# director_facebook_likes                                    1.0
# title_year                                                            1.0
# num_voted_users
#
#                           num_voted_users
# num_user_for_reviews             0.896937
# facenumber_in_poster
# aspect_ratio
# actor_2_facebook_likes
# movie_facebook_likes
# actor_1_facebook_likes
# duration
# actor_3_facebook_likes
# num_critic_for_reviews           0.800632
# cast_total_facebook_likes
# budget
# gross
# director_facebook_likes
# title_year
# num_voted_users                       1.0

# %%
sns.heatmap(x_train.corr(),annot=True,fmt='.1f',mask = np.triu(np.ones_like(x_train.corr(), dtype=bool))|(abs(x_train.corr())<0.7))
# Out:
# <AxesSubplot:>

# %%
# VIF starts at 1 and has no upper limit
# VIF = 1, no correlation between the independent variable and the other variables
# VIF exceeding 5 or 10 indicates high multicollinearity between this independent variable and the others
vif=pd.DataFrame()
vif['features']=x_train.columns
vif['vif']=[variance_inflation_factor(x_train.values,i) for i in range(x_train.shape[1])]
vif.sort_values(by=['vif'])
# Out:
#                      features        vif
# 1        facenumber_in_poster   1.067956
# 12    director_facebook_likes   1.082957
# 4        movie_facebook_likes   1.088280
# 2                aspect_ratio   1.180205
# 6                    duration   1.228234
# 10                     budget   1.625332
# 11                      gross   1.634747
# 13                 title_year   1.670189
# 7      actor_3_facebook_likes   4.008806
# 8      num_critic_for_reviews   4.184276
# 3      actor_2_facebook_likes   4.982595
# 0        num_user_for_reviews   6.362953
# 14            num_voted_users   7.138904
# 5      actor_1_facebook_likes  22.863388
# 9   cast_total_facebook_likes  34.406482

# %%
from sklearn.feature_selection import SelectFromModel
selector = SelectFromModel(estimator=LogisticRegression(random_state=100)).fit(x_train, y_train)
selector.get_support(indices=True)
# Out:
# array([ 0,  5,  6,  9, 10, 14])

# %%
for i in selector.get_support(indices=True).tolist():
    print(x_train.columns[i])
# Out:
# num_user_for_reviews
# actor_1_facebook_likes
# duration
# cast_total_facebook_likes
# budget
# num_voted_users

# %%
selected_features_1=x_train.columns[selector.get_support(indices=True)].tolist()
selected_features_1
# Out:
# ['num_user_for_reviews',
#  'actor_1_facebook_likes',
#  'duration',
#  'cast_total_facebook_likes',
#  'budget',
#  'num_voted_users']

# %%
selected_features=list(set(x_train.columns)-set(['actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes','num_critic_for_reviews','num_user_for_reviews']))

# %%
x_train[selected_features].corr().mask(x_train[selected_features].corr().abs()<0.7,'')
# Out:
#                           facenumber_in_poster duration aspect_ratio  \
# facenumber_in_poster                       1.0
# duration                                            1.0
# aspect_ratio                                                     1.0
# cast_total_facebook_likes
# movie_facebook_likes
# budget
# gross
# director_facebook_likes
# title_year
# num_voted_users
#
#                           cast_total_facebook_likes movie_facebook_likes  \
# facenumber_in_poster
# duration
# aspect_ratio
# cast_total_facebook_likes                       1.0
# movie_facebook_likes                                                 1.0
# budget
# gross
# director_facebook_likes
# title_year
# num_voted_users
#
#                           budget gross director_facebook_likes title_year  \
# facenumber_in_poster
# duration
# aspect_ratio
# cast_total_facebook_likes
# movie_facebook_likes
# budget                       1.0
# gross                              1.0
# director_facebook_likes                                    1.0
# title_year                                                            1.0
# num_voted_users
#
#                           num_voted_users
# facenumber_in_poster
# duration
# aspect_ratio
# cast_total_facebook_likes
# movie_facebook_likes
# budget
# gross
# director_facebook_likes
# title_year
# num_voted_users                       1.0

# %%
vif_after=pd.DataFrame()
vif_after['features']=x_train[selected_features].columns
vif_after['vif']=[variance_inflation_factor(x_train[selected_features].values,i) for i in range(x_train[selected_features].shape[1])]
vif_after.sort_values(by=['vif'])
# Out:
#                     features       vif
# 0       facenumber_in_poster  1.034982
# 4       movie_facebook_likes  1.071237
# 7    director_facebook_likes  1.079528
# 2               aspect_ratio  1.171700
# 1                   duration  1.209956
# 8                 title_year  1.271373
# 3  cast_total_facebook_likes  1.427196
# 6                      gross  1.576121
# 5                     budget  1.615244
# 9            num_voted_users  1.971153

# %% [markdown]
# #### Model

# %% [markdown]
# ##### train

# %%
lr=LogisticRegression(random_state=100)
lr.fit(x_train[selected_features],y_train)
# Out:
# LogisticRegression(random_state=100)

# %%
y_train_pred=pd.DataFrame(lr.predict(x_train[selected_features]))

# %%
print("Classification Report: \n", metrics.classification_report(y_train, y_train_pred,target_names=y_labels))
print("Accuracy on train:  ",lr.score(x_train[selected_features],y_train).round(3),'\n')
cf=metrics.confusion_matrix(y_train,y_train_pred).round(3)
sns.heatmap(cf,annot=True,cmap='Blues',yticklabels=y_labels,xticklabels=y_labels)
plt.ylabel("True Label")
plt.xlabel("Predict Label")
plt.show()
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#     imdb_low       0.74      0.76      0.75      1480
#    imdb_high       0.75      0.73      0.74      1493
#
#     accuracy                           0.74      2973
#    macro avg       0.74      0.74      0.74      2973
# weighted avg       0.74      0.74      0.74      2973
#
# Accuracy on train:   0.744

# %% [markdown]
# ##### test

# %%
y_test_pred=pd.DataFrame(lr.predict(x_test[selected_features]))

# %% [markdown]
# #### Validation

# %%
print("Classification Report: \n", metrics.classification_report(y_test, y_test_pred,target_names=y_labels))
print("Accuracy on train:  ",lr.score(x_test[selected_features],y_test).round(3),'\n')
cf=metrics.confusion_matrix(y_test,y_test_pred).round(3)
sns.heatmap(cf,annot=True,cmap='Blues',yticklabels=y_labels,xticklabels=y_labels)
plt.ylabel("True Label")
plt.xlabel("Predict Label")
plt.show()
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#     imdb_low       0.75      0.76      0.76       635
#    imdb_high       0.76      0.75      0.75       640
#
#     accuracy                           0.75      1275
#    macro avg       0.75      0.75      0.75      1275
# weighted avg       0.75      0.75      0.75      1275
#
# Accuracy on train:   0.754

# %%
result=pd.DataFrame()
result['normalized_features']=lr.feature_names_in_
result['coef']=lr.coef_[0]
result['exp_coef']=np.exp(lr.coef_[0])
result.loc[len(result)]=["intercept",lr.intercept_[0],np.exp(lr.intercept_[0])]
result.sort_values(by=['exp_coef'])
# Out:
#           normalized_features      coef  exp_coef
# 5                      budget -0.649353  0.522384
# 3   cast_total_facebook_likes -0.359905  0.697743
# 6                       gross -0.282952  0.753556
# 8                  title_year -0.272996  0.761096
# 0        facenumber_in_poster -0.087223  0.916473
# 2                aspect_ratio  0.016934  1.017078
# 10                  intercept  0.038063  1.038797
# 7     director_facebook_likes  0.042307  1.043214
# 4        movie_facebook_likes  0.132315  1.141468
# 1                    duration  0.374630  1.454452
# 9             num_voted_users  1.399221  4.052043

# %%
from yellowbrick.classifier import ROCAUC
visualizer = ROCAUC(LogisticRegression(random_state=100), classes=y_labels)
visualizer.fit(x_train[selected_features], y_train)        # Fit the training data to the visualizer
visualizer.score(x_test[selected_features], y_test)        # Evaluate the model on the test data
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'ROC Curves for LogisticRegression'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
# #### All features Model

# %%
lr_all=LogisticRegression()
lr_all.fit(x_train,y_train)
y_test_pred_all=pd.DataFrame(lr_all.predict(x_test))
print("Classification Report: \n", metrics.classification_report(y_test, y_test_pred,target_names=y_labels))
cf=metrics.confusion_matrix(y_test,y_test_pred).round(3)
sns.heatmap(cf,annot=True,cmap='Blues',fmt='.0f',yticklabels=y_labels,xticklabels=y_labels)
plt.ylabel("True Label")
plt.xlabel("Predict Label")
plt.show()
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#     imdb_low       0.75      0.76      0.76       635
#    imdb_high       0.76      0.75      0.75       640
#
#     accuracy                           0.75      1275
#    macro avg       0.75      0.75      0.75      1275
# weighted avg       0.75      0.75      0.75      1275

# %%
from yellowbrick.classifier import ROCAUC
visualizer = ROCAUC(LogisticRegression(), classes=y_labels)
visualizer.fit(x_train, y_train)        # Fit the training data to the visualizer
visualizer.score(x_test, y_test)        # Evaluate the model on the test data
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'ROC Curves for LogisticRegression'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %%
result_all=pd.DataFrame()
result_all['features']=lr_all.feature_names_in_
result_all['coef']=lr_all.coef_[0]
result_all['exp_coef']=np.exp(lr_all.coef_[0])
result_all.loc[len(result_all)]=["intercept",lr_all.intercept_[0],np.exp(lr_all.intercept_[0])]
result_all.sort_values(by=['exp_coef'])
# Out:
#                      features      coef  exp_coef
# 10                     budget -0.639923  0.527333
# 9   cast_total_facebook_likes -0.593833  0.552206
# 0        num_user_for_reviews -0.530714  0.588185
# 13                 title_year -0.331930  0.717537
# 7      actor_3_facebook_likes -0.280069  0.755732
# 11                      gross -0.247862  0.780467
# 1        facenumber_in_poster -0.103244  0.901907
# 3      actor_2_facebook_likes  0.006635  1.006657
# 2                aspect_ratio  0.025398  1.025723
# 12    director_facebook_likes  0.027276  1.027651
# 8      num_critic_for_reviews  0.043826  1.044801
# 15                  intercept  0.047962  1.049131
# 4        movie_facebook_likes  0.141445  1.151937
# 6                    duration  0.403866  1.497603
# 5      actor_1_facebook_likes  0.431485  1.539542
# 14            num_voted_users  1.843143  6.316361
